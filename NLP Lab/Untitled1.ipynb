# %%
# pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
def fetch_webpage_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None

# %%
def clean_text(html_content):
   
    soup = BeautifulSoup(html_content, 'html.parser')
    text_content = re.sub(r'<.*?>', '', soup.get_text(separator=' ', strip=True))
    text_content = re.sub(r'[^a-zA-Z\s]', '', text_content)

    text_content = re.sub(r'\s+', ' ', text_content)

    return text_content

# %%
url = input("Enter the URL: ")
webpage_content = fetch_webpage_content(url)
# Out:
# Enter the URL: https://en.wikipedia.org/wiki/A._P._J._Abdul_Kalam

# %%
if webpage_content:
    cleaned_text = clean_text(webpage_content)
    print(cleaned_text)
# Out:
# A P J Abdul Kalam Wikipedia Jump to content Main menu Main menu move to sidebar hide Navigation Main page Contents Current events Random article About Wikipedia Contact us Donate Contribute Help Learn to edit Community portal Recent changes Upload file Languages Language links are at the top of the page Search Search Create account Log in Personal tools Create account Log in Pages for logged out editors learn more Contributions Talk Contents move to sidebar hide Top 1 Early life and education 2 Career as a scientist 3 Presidency 4 Postpresidency 5 Death Toggle Death subsection 51 Reactions 52 Memorial 6 Personal life 7 Religious and spiritual views Toggle Religious and spiritual views subsection 71 Islam 72 Syncretism 73 Pramukh Swami as Guru 8 Writings 9 Awards and honours Toggle Awards and honours subsection 91 Island 92 Road 93 Plant species 94 Other awards and honours 10 Legacy 11 Books documentaries and popular culture 12 See also 13 References 14 External links Toggle the table
# ...

# %%
def get_unique_words(text):
    words = nltk.word_tokenize(text)

    unique_words = list(set(words))
    
    print(len(unique_words))

    return unique_words

# %%
get_unique_words(cleaned_text)
# Out:
# 4330
# ['System',
#  'Wikipedia',
#  'Azad',
#  'secondtolast',
#  'doing',
#  'Pataskar',
#  'Roddam',
#  'Conduct',
#  'Varadhan',
#  'Punya',
#  'overwhelmed',
#  '15',
#  'Multi',
#  'Royal',
#  'Honours',
#  'Disney',
#  'Complex',
#  'money',
#  'television',
#  'proprietary',
#  'helping',
#  'Abd',
#  'governments',
#  'Giri',
#  'proposed',
#  'seer',
#  'Sister',
#  '9780739102176',
#  'Aswathi',
#  'truly',
#  'remained',
#  'Asim',
#  '202',
#  'unrealised',
#  'were',
#  'pharmabizcom',
#  'Stone',
#  'Santidev',
#  'Upadhyaya',
#  'institutions',
#  '24',
#  '226',
#  'unit',
#  'Tobgay',
#  'childhood',
#  'SARAL',
#  '2007',
#  'Important',
#  'alumni',
#  'VLSRSAM',
#  'features',
#  'Mashelkar',
#  'Chattopadhyay',
#  'Publishing',
#  'Propulsion',
#  'G',
#  'Mohanty',
#  'Exploration',
#  '97',
#  'trading',
#  'Wire',
#  'Mortar',
#  'Active',
#  'friendly',
#  'Degrees',
#  'gift',
#  'Can',
#  'Sundaram',
#  'expresses',
#  'making',
#  'paid',
#  'Use',
# ...

# %%
# pip install nltk

# %%
import nltk

# %%
# nltk.download('punkt')

# %%
def prepare_word_list(text):
    # Tokenize the text into a list of words
    words = nltk.word_tokenize(text)
    return words

# %%
prepare_word_list(cleaned_text)
# Out:
# ['A.',
#  'P.',
#  'J.',
#  'Abdul',
#  'Kalam',
#  '-',
#  'Wikipedia',
#  'Jump',
#  'to',
#  'content',
#  'Main',
#  'menu',
#  'Main',
#  'menu',
#  'move',
#  'to',
#  'sidebar',
#  'hide',
#  'Navigation',
#  'Main',
#  'page',
#  'Contents',
#  'Current',
#  'events',
#  'Random',
#  'article',
#  'About',
#  'Wikipedia',
#  'Contact',
#  'us',
#  'Donate',
#  'Contribute',
#  'Help',
#  'Learn',
#  'to',
#  'edit',
#  'Community',
#  'portal',
#  'Recent',
#  'changes',
#  'Upload',
#  'file',
#  'Languages',
#  'Language',
#  'links',
#  'are',
#  'at',
#  'the',
#  'top',
#  'of',
#  'the',
#  'page',
#  '.',
#  'Search',
#  'Search',
#  'Create',
#  'account',
#  'Log',
#  'in',
#  'Personal',
#  'tools',
#  'Create',
#  'account',
#  'Log',
#  'in',
#  'Pages',
#  'for',
#  'logged',
#  'out',
#  'editors',
#  'learn',
#  'more',
#  'Contributions',
#  'Talk',
#  'Contents',
#  'move',
#  'to',
#  'sidebar',
#  'hide',
#  '(',
#  'Top',
#  ')',
#  '1',
#  'Early',
# ...

# %%
def prepare_sentence_list(text):
    sentences = nltk.sent_tokenize(text)
    return sentences

# %%
prepare_sentence_list(cleaned_text)
# Out:
# ['A. P. J. Abdul Kalam - Wikipedia Jump to content Main menu Main menu move to sidebar hide Navigation Main page Contents Current events Random article About Wikipedia Contact us Donate Contribute Help Learn to edit Community portal Recent changes Upload file Languages Language links are at the top of the page.',
# ...

# %%
# def prepare_paragraph_list(text):
#     soup = BeautifulSoup(text, 'html.parser')

#     ps=soup.find_all("p")
#     text = ""
#     for p in ps:
#         text+=p.text.strip()
#     return text

# %%
# prepare_paragraph_list(webpage_content)

# %%
soup = BeautifulSoup(webpage_content, 'html.parser')

for data in soup.find_all("p"):
    print(data.get_text())
# Out:
# Books and publications
#
#
#
# Avul Pakir Jainulabdeen Abdul Kalam BR (/ˈɑːbdəl kəˈlɑːm/ ⓘ; 15 October 1931 – 27 July 2015) was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974.[5]
#
# ...

# %%
anchors = soup.find_all("a")
for a in anchors:
    print(a["href"])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=A.+P.+J.+Abdul+Kalam
# /w/index.php?title=Special:UserLogin&returnto=A.+P.+J.+Abdul+Kalam
# /w/index.php?title=Special:CreateAccount&returnto=A.+P.+J.+Abdul+Kalam
# /w/index.php?title=Special:UserLogin&returnto=A.+P.+J.+Abdul+Kalam
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Career_as_a_scientist
# #Presidency
# #Post-presidency
# #Death
# #Reactions
# ...

# %%
def get_unique_words(text):
    words = nltk.word_tokenize(text)

    unique_words = list(set(words))
    
    print(len(unique_words))

    return unique_words

# %%
get_unique_words(cleaned_text)
# Out:
# 4452
# ['System',
#  'Wikipedia',
#  'Azad',
#  'doing',
#  'Pataskar',
#  'Roddam',
#  'Conduct',
#  'Varadhan',
#  'Punya',
#  'overwhelmed',
#  '15',
#  'Multi',
#  'Royal',
#  'Honours',
#  'St.',
#  'Complex',
#  'money',
#  'television',
#  'proprietary',
#  'helping',
#  'Abd',
#  'Kalam.pdf',
#  'Giri',
#  'proposed',
#  'seer',
#  'Sister',
#  '978-81-250-2477-4',
#  'truly',
#  'Aswathi',
#  'remained',
#  'Asim',
#  '202',
#  'unrealised',
#  'were',
#  'Kapothaka',
#  'Stone',
#  'Santidev',
#  'Upadhyaya',
#  '19:06',
#  'institutions',
#  '24',
#  '...',
#  'unit',
#  'Tobgay',
#  'childhood',
#  '226',
#  'SARAL',
#  '2007',
#  'Important',
#  'alumni',
#  'features',
#  'Mashelkar',
#  'Chattopadhyay',
#  'Publishing',
#  'Propulsion',
#  'G',
#  'Mohanty',
#  'Exploration',
#  '97',
#  'trading',
#  'Wire',
#  'Mortar',
#  'Active',
#  'friendly',
#  'Degrees',
#  'gift',
#  'Can',
#  'Sundaram',
#  'expresses',
#  'making',
#  'paid',
#  'Use',
#  'seek',
# ...
